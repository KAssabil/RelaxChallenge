# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV,train_test_split

# %%
os.chdir('/Users/kofiassabil/Downloads')

# %%
df_engage = pd.read_csv('takehome_user_engagement.csv')
df_users = pd.read_csv('takehome_users.csv',encoding='latin-1')
df_engage = df_engage.set_index(pd.DatetimeIndex(df_engage['time_stamp']))

# %%
df_engage.head()
# Out:
#                               time_stamp  user_id  visited
# time_stamp
# 2014-04-22 03:53:30  2014-04-22 03:53:30        1        1
# 2013-11-15 03:45:04  2013-11-15 03:45:04        2        1
# 2013-11-29 03:45:04  2013-11-29 03:45:04        2        1
# 2013-12-09 03:45:04  2013-12-09 03:45:04        2        1
# 2013-12-25 03:45:04  2013-12-25 03:45:04        2        1

# %%
df_users.head()
# Out:
#    object_id        creation_time               name  \
# 0          1  2014-04-22 03:53:30     Clausen August
# 1          2  2013-11-15 03:45:04      Poole Matthew
# 2          3  2013-03-19 23:14:52  Bottrill Mitchell
# 3          4  2013-05-21 08:09:28    Clausen Nicklas
# 4          5  2013-01-17 10:14:20          Raw Grace
#
#                         email creation_source  last_session_creation_time  \
# 0    AugustCClausen@yahoo.com    GUEST_INVITE                1.398139e+09
# 1      MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 2  MitchellBottrill@gustr.com      ORG_INVITE                1.363735e+09
# 3   NicklasSClausen@yahoo.com    GUEST_INVITE                1.369210e+09
# 4          GraceRaw@yahoo.com    GUEST_INVITE                1.358850e+09
#
#    opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 0                         1                           0      11
# 1                         0                           0       1
# ...

# %%
#group by user,date & week, sum of number of visits per week
#remove na weeks
group = df_engage.groupby('user_id').resample('1W').sum()
group = group[group['user_id'].isnull()==False].drop('user_id',axis=1)

# %%
group.head()
# Out:
#                     visited
# user_id time_stamp
# 1       2014-04-27        1
# 2       2013-11-17        1
#         2013-11-24        0
#         2013-12-01        1
#         2013-12-08        0

# %%
#weeks that had more 3 or more visits and group them
#remove users with no weeks with 3 or more visits
users_active = group['visited']>= 3
users_active = users_active.groupby(level=0).apply(np.sum)
users_active = users_active[users_active!=0]
users_active = pd.DataFrame(users_active,index=users_active.index)
users_active.head(10)
# Out:
#          visited
# user_id
# 2              1
# 10            52
# 20             1
# 33             1
# 42            68
# 43             1
# 53             1
# 63            62
# 69            91
# 74             8

# %%
active_users = users_active.merge(df_users,left_index=True,right_on='object_id',how='inner')
active_users.head()
# Out:
#     visited  object_id        creation_time            name  \
# 1         1          2  2013-11-15 03:45:04   Poole Matthew
# 9        52         10  2013-01-16 22:08:03    Santos Carla
# 19        1         20  2014-03-06 11:46:38   Helms Mikayla
# 32        1         33  2014-03-11 06:29:09     Araujo José
# 41       68         42  2012-11-11 19:05:07  Pinto Giovanna
#
#                             email creation_source  last_session_creation_time  \
# 1          MatthewPoole@gustr.com      ORG_INVITE                1.396238e+09
# 9   CarlaFerreiraSantos@gustr.com      ORG_INVITE                1.401833e+09
# 19             lqyvjilf@uhzdq.com          SIGNUP                1.401364e+09
# 32     JoseMartinsAraujo@cuvox.de    GUEST_INVITE                1.401518e+09
# 41    GiovannaCunhaPinto@cuvox.de          SIGNUP                1.401045e+09
#
#     opted_in_to_mailing_list  enabled_for_marketing_drip  org_id  \
# 1                          0                           0       1
# ...

# %%
active_users['Active']=1
#Add Active column to origional Data
df_users['Active']=int(0)
df_users.iloc[list(active_users.index),10]=1
model_data = df_users.set_index('object_id').sort_index()
model_data = model_data.drop([ 'name', 'email','last_session_creation_time',],axis=1)
date_feature = model_data.pop('creation_time')
model_data.head()
# Out:
#           creation_source  opted_in_to_mailing_list  \
# object_id
# 1            GUEST_INVITE                         1
# 2              ORG_INVITE                         0
# 3              ORG_INVITE                         0
# 4            GUEST_INVITE                         0
# 5            GUEST_INVITE                         0
#
#            enabled_for_marketing_drip  org_id  invited_by_user_id  Active
# object_id
# 1                                   0      11             10803.0       0
# 2                                   0       1               316.0       1
# 3                                   0      94              1525.0       0
# 4                                   0       1              5151.0       0
# 5                                   0     193              5240.0       0

# %%
model_data['invited_by_user_id'] = model_data['invited_by_user_id'].fillna(0)
model_data['invited_by_user_id'] = model_data['invited_by_user_id'].apply(
        lambda x: 1 if x!=0 else 0)
model_data = pd.get_dummies(data=model_data,columns=['creation_source'])

# %%
org = model_data.groupby('org_id').sum()
org_cata = []
for i in model_data['org_id']:
    cata = org.loc[i,'Active']
    org_cata.append(cata)
model_data['org_id'] = org_cata

model_data = pd.get_dummies(data=model_data,columns=['org_id'])
model_data.head()
# Out:
#            opted_in_to_mailing_list  enabled_for_marketing_drip  \
# object_id
# 1                                 1                           0
# 2                                 0                           0
# 3                                 0                           0
# 4                                 0                           0
# 5                                 0                           0
#
#            invited_by_user_id  Active  creation_source_GUEST_INVITE  \
# object_id
# 1                           1       0                             1
# 2                           1       1                             0
# 3                           1       0                             0
# 4                           1       0                             1
# 5                           1       0                             1
#
#            creation_source_ORG_INVITE  creation_source_PERSONAL_PROJECTS  \
# object_id
# ...

# %%
y = model_data.pop('Active')
x = model_data
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.25,random_state=42)

# %%
grad_boost = GradientBoostingClassifier(max_features='sqrt')
para = {'n_estimators':[40,45,50,55,60],'learning_rate':[.01,0.02,0.03,0.04,0.05],
              'max_depth':[1,2,3,4,5]}
grid1 = GridSearchCV(estimator=grad_boost,param_grid=para,
                     scoring='accuracy',cv=5)
grid1.fit(x_train,y_train)
best_para_gra = grid1.best_params_
best_acc_gra = grid1.best_score_

print('The Tuned Paratmers ',best_para_gra,'Achieved %s Percent Accuracy' %(best_acc_gra*100))
# Out:
# The Tuned Paratmers  {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 55} Achieved 88.0111111111111 Percent Accuracy

# %%
#importantance of each features in descending order
gbm = GradientBoostingClassifier(max_features='sqrt',
                                 n_estimators=45,learning_rate=.05,max_depth= 3)
gbm.fit(x_train,y_train)
feature_coef = pd.DataFrame(gbm.feature_importances_).transpose()
feature_coef.columns = list(model_data.columns)
feature_coef.index = ['GBM'] 
feature_coef.transpose().sort_values(by='GBM',ascending=False)
# Out:
#                                          GBM
# creation_source_PERSONAL_PROJECTS   0.180317
# org_id_0                            0.151192
# org_id_5                            0.146656
# org_id_1                            0.108725
# org_id_11                           0.093732
# org_id_6                            0.075185
# creation_source_GUEST_INVITE        0.049259
# org_id_12                           0.031375
# opted_in_to_mailing_list            0.028662
# creation_source_SIGNUP_GOOGLE_AUTH  0.025401
# creation_source_SIGNUP              0.015545
# enabled_for_marketing_drip          0.014536
# creation_source_ORG_INVITE          0.014144
# org_id_7                            0.013758
# org_id_14                           0.012311
# org_id_2                            0.011633
# org_id_4                            0.010185
# org_id_13                           0.005971
# org_id_10                           0.004790
# org_id_3                            0.003135
# ...
